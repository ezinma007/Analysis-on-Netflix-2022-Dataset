# %%
# importing the datasets
import pandas as pd
data = pd.read_csv("netflix_titles.csv")


                        # to import pandas library

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Some basic information about the dataset

# %% [markdown]
# ## 1. head()

# %%
#The head() function, to show 5 top records of the data set
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ## 2. tail()

# %%
#The tail() function, to show bottom 5 records of the data set
data.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# ## 3. shape

# %%
#The shape function, is used to show the number of rows and columns
data.shape
# Out:
# (8807, 12)

# %% [markdown]
# ## 4. size

# %%
# The size function is used to show total values(elements) in a dataset
data.size
# Out:
# 105684

# %% [markdown]
# ## 5. columns

# %%
#The columns function is used to show each column name
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# ## 6. dtypes

# %%
#The dtypes fuction shows the datatype of each column
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# ## 7. info()

# %%
# The info() function shows indexes, columns, data-types of each column, memory at once
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# # TASK 1
# ## Is there any duplicate records in this dataset? If yes, then remove the duplicate record
#
# ## duplicate()

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.shape
# Out:
# (8807, 12)

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
data[data.duplicated()]  # To see the duplicate records   #There are no duplicates
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# # TASK 2
#
# ## Is there any Null Value present in any column? Show with Heatmap.
#
# ## isnull()

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data[data.isnull()]  # to show null values
# Out:
#      show_id type title director cast country date_added  release_year rating  \
# 0        NaN  NaN   NaN      NaN  NaN     NaN        NaN           NaN    NaN
# 1        NaN  NaN   NaN      NaN  NaN     NaN        NaN           NaN    NaN
# 2        NaN  NaN   NaN      NaN  NaN     NaN        NaN           NaN    NaN
# 3        NaN  NaN   NaN      NaN  NaN     NaN        NaN           NaN    NaN
# 4        NaN  NaN   NaN      NaN  NaN     NaN        NaN           NaN    NaN
# ...      ...  ...   ...      ...  ...     ...        ...           ...    ...
# 8802     NaN  NaN   NaN      NaN  NaN     NaN        NaN           NaN    NaN
# 8803     NaN  NaN   NaN      NaN  NaN     NaN        NaN           NaN    NaN
# 8804     NaN  NaN   NaN      NaN  NaN     NaN        NaN           NaN    NaN
# 8805     NaN  NaN   NaN      NaN  NaN     NaN        NaN           NaN    NaN
# 8806     NaN  NaN   NaN      NaN  NaN     NaN        NaN           NaN    NaN
#
# ...

# %%
data.isnull().sum()  # to show the count of null values in each column
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ## seaborn library (heat-map)

# %%
import seaborn as sns  # to import seaborn library
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull()) # Using heatmap to show null value count
# Out:
# <Axes: >

# %% [markdown]
# ###  (Since some columns do not contain null values, i will only drop null values when i need to for accurate analysis)

# %% [markdown]
# ##  1. For the show 'You', What is the show id and who is the Director?

# %% [markdown]
# ## isin()

# %%
data['title']
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: object

# %%
data['title'].isin(['You']) # To show all records of a particular item in  a column
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Name: title, Length: 8807, dtype: bool

# %%
data[data['title'].isin(['You'])] #It will show the results of a particular item in any column
# Out:
#      show_id     type title            director  \
# 3096   s3097  TV Show   You  Lee Toland Krieger
#
#                                                    cast        country  \
# 3096  Penn Badgley, Elizabeth Lail, Shay Mitchell, J...  United States
#
#              date_added  release_year rating   duration  \
# 3096  December 26, 2019          2019  TV-MA  2 Seasons
#
#                                          listed_in  \
# 3096  Crime TV Shows, Romantic TV Shows, TV Dramas
#
#                                             description
# 3096  Obsessed with an aspiring writer, a charming b...

# %%
you = data[data['title'].isin(['You'])]
you['director']
# Out:
# 3096    Lee Toland Krieger
# Name: director, dtype: object

# %% [markdown]
# ## 2. What year has the highest amount of Tv shows and Movies added to Netflix? Show on a bar Graph.

# %% [markdown]
# ## to_datetime

# %%
data['Date_N'] = pd.to_datetime(data['date_added']) #Creates a new column named "Date_N" and convert a column named "date_added" in the DataFrame from a string format to a datetime format.

# %%
data.dtypes # Checking the data type of the newly created column [Date_N]
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Date_N          datetime64[ns]
# dtype: object

# %% [markdown]
# ## dt.year.value_counts()

# %%
year_counts= data['Date_N'].dt.year.value_counts()    #It counts the occurence of all individual years in date column.
year_counts
# Out:
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %% [markdown]
# ## Bar Graph

# %%
plt.figure(figsize=(10,6)) # increase the figure size
sns.barplot(x=year_counts.index, y=year_counts.values, color='red') #show data on a bargraph
# Out:
# <Axes: >

# %% [markdown]
# ## How many movies and TV shows are in the datasets? Show with bar graph.

# %% [markdown]
# ### groupby()

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N
# 0  As her father nears the end of his life, filmm... 2021-09-25
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24

# %%
data.groupby('type').type.count() # To group all unique items of a column and count their count
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %% [markdown]
# ## countplot()

# %%
sns.countplot(x= 'type', data= data)  # To group the count of all unique items of a column in the form of a bar graph
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %% [markdown]
# ## Show all the movies released in the year 2018?

# %% [markdown]
# ### Creating a new column

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data['Year'] = data['Date_N'].dt.year  # To create a new yr column. It will consider only the year

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ### Filtering

# %%
data[(data['type'] == 'Movie') & (data['Year'] == 2018)]
# Out:
#      show_id   type                        title                     director  \
# 4229   s4230  Movie  Bill Hicks: One Night Stand             John Fortenberry
# 4230   s4231  Movie      Bill Hicks: Reflections                          NaN
# 4231   s4232  Movie       Bill Hicks: Relentless                  Chris Bould
# 4232   s4233  Movie      Bill Hicks: Revelations                  Chris Bould
# 4233   s4234  Movie         Bill Hicks: Sane Man  Kevin Booth, David Johndrow
# ...      ...    ...                          ...                          ...
# 8778   s8779  Movie                  Yes or No 2      Saratswadee Wongsomphet
# 8779   s8780  Movie                Yes or No 2.5            Kirati Nakintanon
# 8784   s8785  Movie         Yoko and His Friends                          NaN
# 8794   s8795  Movie                       اشتباك                 Mohamed Diab
# 8799   s8800  Movie                        Zenda               Avadhoot Gupte
#
# ...

# %%
len(data[(data['type'] == 'Movie') & (data['Year'] == 2018)]) #To get the number of movies added in the year 2018.
# Out:
# 1237

# %% [markdown]
# ## Show only the title of all TV Shows that were released in Nigeria only

# %%
data.head(3)  #check the dataset
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
data [ (data['type'] == 'TV Show') & (data['country'] == 'Nigeria') ] #show all TV shows released in Nigeria
# Out:
#      show_id     type                                 title      director  \
# 49       s50  TV Show                     Castle and Castle           NaN
# 198     s199  TV Show  King of Boys: The Return of the King  Kemi Adetiba
# 1654   s1655  TV Show                             Before 30     BB Sasore
# 2102   s2103  TV Show                      Ojos in d' House           NaN
# 2148   s2149  TV Show                          The Governor           NaN
# 2906   s2907  TV Show                           On the Real   Tosin Coker
# 2938   s2939  TV Show                     Fifty: The Series           NaN
# 2992   s2993  TV Show                 Sons of the Caliphate           NaN
# 3130   s3131  TV Show                   Crazy, Lovely, Cool  Obi Emelonye
#
#                                                    cast  country  \
# 49    Richard Mofe-Damijo, Dakore Akande, Bimbo Manu...  Nigeria
# 198   Sola Sobowale, Toni Tones, Richard Mofe-Damijo...  Nigeria
# ...

# %%
data [ (data['type'] == 'TV Show') & (data['country'] == 'Nigeria') ] ['title']  #Show just the Titles
# Out:
# 49                         Castle and Castle
# 198     King of Boys: The Return of the King
# 1654                               Before 30
# 2102                        Ojos in d' House
# 2148                            The Governor
# 2906                             On the Real
# 2938                       Fifty: The Series
# 2992                   Sons of the Caliphate
# 3130                     Crazy, Lovely, Cool
# Name: title, dtype: object

# %%
len(data [ (data['type'] == 'TV Show') & (data['country'] == 'Nigeria') ] ['title']) #show the number of Tv shows released in Nigeria
# Out:
# 9

# %% [markdown]
# ## Show Top directors who gave the highest number of TV shows and movies to Netflix

# %% [markdown]
# ### value_counts()

# %%
data['director'].value_counts()  #shows count for directors
# Out:
# Rajiv Chilaka                     19
# Raúl Campos, Jan Suter            18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
#                                   ..
# Raymie Muzquiz, Stu Livingston     1
# Joe Menendez                       1
# Eric Bross                         1
# Will Eisenberg                     1
# Mozez Singh                        1
# Name: director, Length: 4528, dtype: int64

# %%
data['director'].value_counts().head(10) #shows count of top 10 directors
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %% [markdown]
# ## Show all records where "rating is PG-13 and type is Movie" or "country is United Kingdom"

# %% [markdown]
# ### Filtering And, Or Operators

# %%
data[(data['rating'] == 'PG-13') & (data['type'] == 'Movie')] #show record where rating is PG-13 and type is Movie
# Out:
#      show_id   type                    title         director  \
# 0         s1  Movie     Dick Johnson Is Dead  Kirsten Johnson
# 9        s10  Movie             The Starling   Theodore Melfi
# 27       s28  Movie                Grown Ups     Dennis Dugan
# 28       s29  Movie               Dark Skies    Scott Stewart
# 29       s30  Movie                 Paranoia   Robert Luketic
# ...      ...    ...                      ...              ...
# 8757   s8758  Movie       World Trade Center     Oliver Stone
# 8764   s8765  Movie               Wyatt Earp  Lawrence Kasdan
# 8766   s8767  Movie                      XXx        Rob Cohen
# 8767   s8768  Movie  XXX: State of the Union     Lee Tamahori
# 8782   s8783  Movie              Yoga Hosers      Kevin Smith
#
#                                                    cast  \
# 0                                                   NaN
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# ...

# %%
data[(data['rating'] == 'PG-13') & (data['type'] == 'Movie') | (data['country'] == 'United Kingdom')] 

#show record where rating is PG-13 and type is Movie or country is United Kingdom
# Out:
#      show_id     type                          title         director  \
# 0         s1    Movie           Dick Johnson Is Dead  Kirsten Johnson
# 8         s9  TV Show  The Great British Baking Show  Andy Devonshire
# 9        s10    Movie                   The Starling   Theodore Melfi
# 27       s28    Movie                      Grown Ups     Dennis Dugan
# 28       s29    Movie                     Dark Skies    Scott Stewart
# ...      ...      ...                            ...              ...
# 8764   s8765    Movie                     Wyatt Earp  Lawrence Kasdan
# 8766   s8767    Movie                            XXx        Rob Cohen
# 8767   s8768    Movie        XXX: State of the Union     Lee Tamahori
# 8782   s8783    Movie                    Yoga Hosers      Kevin Smith
# 8786   s8787    Movie                   You Can Tutu      James Brown
#
#                                                    cast         country  \
# ...

# %% [markdown]
# ## How many movies or shows was Tom cruise cast in?

# %%
data[data['cast'] == 'Tom Cruise'] #This code only works when there is a single cast name on a row on the cast column.
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Date_N, Year]
# Index: []

# %%
data[data['cast'].str.contains('Tom Cruise')]  #This code can not work on null values, so a new data frame without null values has to be created.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 data[data['cast'].str.contains('Tom Cruise')]  #This code can not work on null values, so a new data frame without null values has to be created.
#
# File c:\Users\Ezinma\Documents\datascienceproject\my_env\Lib\site-packages\pandas\core\frame.py:3797, in DataFrame.__getitem__(self, key)
#    3794     return self.where(key)
#    3796 # Do we have a (boolean) 1d indexer?
# -> 3797 if com.is_bool_indexer(key):
#    3798     return self._getitem_bool_array(key)
#    3800 # We are left with two options: a single key, and a collection of keys,
#    3801 # We interpret tuples as collections only for non-MultiIndex
#
# File c:\Users\Ezinma\Documents\datascienceproject\my_env\Lib\site-packages\pandas\core\common.py:135, in is_bool_indexer(key)
# ...

# %% [markdown]
# ### This code can not work on null values, so a new data frame without null values has to be created.

# %% [markdown]
# ## Create new dataframe

# %%
data_new = data.dropna() # Drops the rows that contain all or any missing values

# %%
data_new.head()  # Check new data frame
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country          date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# ...

# %%
data_new[data_new['cast'].str.contains('Tom Cruise')] #now use new data frame with the .str.contains() function
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added  release_year rating duration  \
# 341   August 1, 2021          1999      R  189 min
# 1254   March 1, 2021          1988      R  134 min
#
#                        listed_in  \
# 341   Dramas, Independent Movies
# 1254      Classic Movies, Dramas
#
#                                             description     Date_N    Year
# 341   Through chance, history and divine interventio... 2021-08-01  2021.0
# 1254  Motivated by money, a selfish workaholic seeki... 2021-03-01  2021.0

# %% [markdown]
# ## What are the different Ratings defined by Netflix?

# %% [markdown]
# ## nunique()

# %%
data_new['rating'].nunique() #show the number of unique values
# Out:
# 14

# %% [markdown]
# ## unique()

# %%
data_new['rating'].unique() #show the unique values
# Out:
# array(['TV-MA', 'TV-14', 'PG-13', 'PG', 'R', 'TV-PG', 'G', 'TV-Y7',
#        'TV-G', 'TV-Y', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ## How many movies got the TV-14 rating in Canada?

# %%
data_new[(data_new['rating'] == 'TV-14') & (data_new['type'] == 'Movie') & (data_new['country'] == 'Canada')] 

# to get the movies that got the Tv-14 rating in Canada
# Out:
#      show_id   type                                        title  \
# 157     s158  Movie                                     Level 16
# 2769   s2770  Movie               There's Something in the Water
# 3424   s3425  Movie  Martin Matte: La vie, la mort...eh la la..!
# 5973   s5974  Movie                                        #Roxy
# 6192   s6193  Movie                               At First Light
# 6537   s6538  Movie                   Counterfeiting in Suburbia
# 7334   s7335  Movie                            Long Time Running
# 7916   s7917  Movie                   Sadie's Last Days on Earth
# 7936   s7937  Movie                                   Sardaar ji
# 8566   s8567  Movie                         The Wrong Babysitter
#
#                                     director  \
# 157                       Danishka Esterhazy
# 2769                  Ellen Page, Ian Daniel
# 3424                     Jean-François Blais
# 5973                         Michael Kennedy
# ...

# %%
len(data_new[(data_new['rating'] == 'TV-14') & (data_new['type'] == 'Movie') & (data_new['country'] == 'Canada')]) # To get the count
# Out:
# 10

# %% [markdown]
# ## How many TV Shows got the 'R' rating after year 2018?

# %%
data[(data['type'] == 'TV Show') & (data['rating'] == 'R') & (data['Year'] >= 2018)]
# Out:
#      show_id     type                                title           director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    cast country  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#           date_added  release_year rating  duration listed_in  \
# 3893  April 25, 2019          2015      R  1 Season  TV Shows
#
#                                             description     Date_N    Year
# 3893  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %% [markdown]
# ## What is the maximum duration of a Movie on Netflix

# %%
data['duration'].unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
data[['Minutes', 'Unit']] = data['duration'].str.split(' ', expand = True)

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year  \
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0
#
#   Minutes     Unit
# ...

# %% [markdown]
# ### max()

# %%
data_now = data.dropna() #to drop missing values

# %%
data_now['Minutes'].astype(int)
# Out:
# 7       125
# 8         9
# 9       104
# 12      127
# 24      166
#        ...
# 8801     96
# 8802    158
# 8804     88
# 8805     88
# 8806    111
# Name: Minutes, Length: 5332, dtype: int32

# %%
data_now = data_now[data_now['type'] == 'Movie']
data_now
# Out:
#      show_id   type         title             director  \
# 7         s8  Movie       Sankofa         Haile Gerima
# 9        s10  Movie  The Starling       Theodore Melfi
# 12       s13  Movie  Je Suis Karl  Christian Schwochow
# 24       s25  Movie         Jeans           S. Shankar
# 27       s28  Movie     Grown Ups         Dennis Dugan
# ...      ...    ...           ...                  ...
# 8801   s8802  Movie       Zinzana      Majid Al Ansari
# 8802   s8803  Movie        Zodiac        David Fincher
# 8804   s8805  Movie    Zombieland      Ruben Fleischer
# 8805   s8806  Movie          Zoom         Peter Hewitt
# 8806   s8807  Movie        Zubaan          Mozez Singh
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...

# %%
data_now['Minutes'].max()
# Out:
# '99'

# %%
data_now['Minutes'].min()
# Out:
# '100'

# %%
data_now['Minutes'].describe()
# Out:
# count     5185
# unique     188
# top         94
# freq       135
# Name: Minutes, dtype: object

# %%
print(data_now['Minutes'].describe())
# Out:
# count     5185
# unique     188
# top         94
# freq       135
# Name: Minutes, dtype: object

# %% [markdown]
# ## Which Individual Country has one of the highest TV Shows?

# %%
data_tvshow = data[data['type'] == 'TV Show']    #Create new dataframe that has just TV Shows

# %%
data_tvshow.head(2)
# Out:
#   show_id     type          title         director  \
# 1      s2  TV Show  Blood & Water              NaN
# 2      s3  TV Show      Ganglands  Julien Leclercq
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description Minutes     Unit
# 1  After crossing paths at a party, a Cape Town t...       2  Seasons
# 2  To protect his family from a powerful drug lor...       1   Season

# %%
data_tvshow['country'].value_counts()
# Out:
# United States                                    760
# United Kingdom                                   213
# Japan                                            169
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: country, Length: 196, dtype: int64

# %%
data_tvshow['country'].value_counts().head(1)
# Out:
# United States    760
# Name: country, dtype: int64

# %% [markdown]
# ## How can we sort the dataset by Year?

# %%
data.sort_values(by = 'Year').head(2) #sort the dataset by Year
# Out:
#      show_id     type                 title              director  \
# 5957   s5958    Movie  To and From New York  Sorin Dan Mihalcescu
# 6611   s6612  TV Show       Dinner for Five                   NaN
#
#                                                    cast        country  \
# 5957  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
# 6611                                                NaN  United States
#
#             date_added  release_year rating  duration  \
# 5957   January 1, 2008          2006  TV-MA    81 min
# 6611  February 4, 2008          2007  TV-MA  1 Season
#
#                                   listed_in  \
# 5957  Dramas, Independent Movies, Thrillers
# 6611           Stand-Up Comedy & Talk Shows
#
#                                             description Minutes    Unit  \
# 5957  While covering a story in New York City, a Sea...      81     min
# 6611  In each episode, four celebrities join host Jo...       1  Season
#
# ...

# %%
data.sort_values(by = 'Year', ascending = False).head(2) #to see the latest year, use ascending false
# Out:
#     show_id   type                 title         director  \
# 0        s1  Movie  Dick Johnson Is Dead  Kirsten Johnson
# 996    s997  Movie            HOMUNCULUS  Takashi Shimizu
#
#                                                   cast        country  \
# 0                                                  NaN  United States
# 996  Go Ayano, Ryo Narita, Yukino Kishii, Anna Ishi...          Japan
#
#              date_added  release_year rating duration  \
# 0    September 25, 2021          2020  PG-13   90 min
# 996      April 22, 2021          2021  TV-MA  116 min
#
#                                           listed_in  \
# 0                                     Documentaries
# 996  Horror Movies, International Movies, Thrillers
#
#                                            description Minutes Unit  \
# 0    As her father nears the end of his life, filmm...      90  min
# 996  Truth and illusion blurs when a homeless amnes...     116  min
#
#         Date_N    Year
# ...

# %% [markdown]
# ## Find all the instances where:
#
# ## A movie is listed in Comedies
#
# ## OR
#
# ## A TV Show is listed in 'Children & Family Movies'

# %%
data[(data['type'] == 'Movie') & (data['listed_in'] == 'Comedies') | (data['type'] == 'TV Show') & (data['listed_in'] == 'Children & Family Movies')]
# Out:
#      show_id   type                                   title  \
# 27       s28  Movie                               Grown Ups
# 152     s153  Movie           Janoskians: Untold and Untrue
# 182     s183  Movie             Welcome Home Roscoe Jenkins
# 342     s343  Movie                             Major Payne
# 348     s349  Movie                                    Poms
# ...      ...    ...                                     ...
# 8420   s8421  Movie              The Men Who Stare at Goats
# 8433   s8434  Movie  The Naked Gun 2 1/2: The Smell of Fear
# 8536   s8537  Movie                       The Trip to Spain
# 8608   s8609  Movie                        Total Frat Movie
# 8730   s8731  Movie                       Where's the Money
#
#                   director                                               cast  \
# 27            Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# 152           Brett Weiner  Jai Brooks, Luke Brooks, James Yammouni, Danie...
# ...
